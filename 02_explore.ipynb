# %% [markdown]
# # 02 - Exploratory analysis
#
# **Goal:** understand the data well enough that nothing in the optimisation
# output surprises you.
#
# **What you'll learn:** choropleth mapping, distribution diagnostics, and the
# discipline of looking before modelling.
#
# Questions to answer with a figure each:
#
# 1. What is the distribution of canopy fraction across block groups? Is it
#    skewed? Are there zeros?
# 2. Where is canopy concentrated? Map it.
# 3. How does canopy fraction relate to median income, and to population density?
#    Scatter plots with a fitted line - and resist calling it causal.
# 4. How many block groups are already above Denver's 15% target, and how many
#    are below?
# 5. How much would it cost, naively, to bring everyone to 15%? (This is your
#    back-of-envelope check on the optimisation later.)
# 6. Is capacity binding? Plot capacity against the trees needed to reach 15%.
#    Block groups where capacity < need are structurally impossible to fix by
#    planting alone - a genuine finding, not a bug.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from canopy.io import PROCESSED

table = gpd.read_file(PROCESSED / "analysis_table.gpkg")
table.head()

# %%
# TODO: choropleth of canopy_frac

# %%
# TODO: distribution + scatter diagnostics

# %% [markdown]
# ## Write-up cell
#
# Summarise, in prose, the three things you now know that you didn't before
# opening this notebook. If you can't name three, you haven't explored enough.
